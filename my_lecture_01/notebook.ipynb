# %% [markdown]
# These are where lecture notes are...

# %% [markdown]
# There are different ways of changing fonts...
#
# # Big text

# %% [markdown]
# ## slightly smaller
#
# smallest

# %%
print("Hello, world")
# Out:
# Hello, world
